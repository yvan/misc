# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/cpu:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 4904312082767117469, name: "/gpu:0"
#  device_type: "GPU"
#  memory_limit: 11332668621
#  locality {
#    bus_id: 1
#  }
#  incarnation: 17377391831290418700
#  physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:05:00.0"]

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
import random
from collections import Counter

#set threshold
t = 1e-5

# get frequencies of words
vocab_size = len(int_words)
cw = Counter(int_words)

probs = {}

# go through freqs
# convert to probs
for k,v in cw.items():
    probs[k] = 1 - np.sqrt(t/(v/vocab_size))
train_words = [word for word in int_words if random.random() < (1 - probs[word]) ]

# %%
len(train_words)
# Out:
# 4627514

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    r = np.random.choice(window_size, 1)[0]+1
    # Your code here
    start = idx-r if (idx-r) > 0 else 0
    end = idx+r+1
    return words[start:idx]+words[idx+1:end]

# %%
get_target(train_words, 25)
# Out:
# [5234, 1134, 2621, 9016, 4158, 362, 5234, 4863, 7585, 566]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %%
x,y=next(get_batches(int_words, 8))
print(x,'\n\n',y)
print(len(x),'\n\n',len(y))
# Out:
# [5234, 5234, 5234, 5234, 5234, 3081, 3081, 11, 11, 11, 11, 5, 5, 194, 194, 194, 194, 1, 1, 3136, 3136, 3136, 45, 45]
#
#  [3081, 11, 5, 194, 1, 5234, 11, 5, 194, 1, 3136, 11, 194, 11, 5, 1, 3136, 194, 3136, 194, 1, 45, 1, 3136]
# 24
#
#  24

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None])
    labels = tf.placeholder(tf.int32, [None, None])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding),-1,1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding,inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding),stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6006 0.0448 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5839 0.0425 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4333 0.0432 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5390 0.0445 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4313 0.0417 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4872 0.0423 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.4882 0.0422 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5115 0.0431 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4656 0.0433 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3874 0.0422 sec/batch
# Nearest to was: wheel, slidell, forbids, containers, proleptic, lothair, hatti, oresund,
# Nearest to over: nt, tungusic, acquiring, bugzilla, raping, hsv, deluxe, prostaglandins,
# Nearest to these: greig, nw, paekche, beauty, tennant, kant, gas, contemplative,
# Nearest to also: caledonian, acquaintances, cholas, auchinleck, tunku, revive, chlorofluorocarbons, minimalist,
# Nearest to such: rix, virgil, vaucher, cheltenham, counteracting, minivan, stalking, til,
# Nearest to been: impassable, flow, brienne, chlorination, cagliari, patinkin, sensuous, critias,
# Nearest to their: dare, traversed, serbo, complies, skat, cb, alabaster, venlafaxine,
# Nearest to years: uncodified, wishing, bulgar, svg, searching, vyacheslav, hodge, javanese,
# Nearest to derived: riff, greeting, rene, northern, penises, peralta, graphemes, tully,
# Nearest to hit: pullout, fanshawe, briefly, mla, monophosphate, marisco, homogeneity, collin,
# Nearest to woman: networked, harpist, a, kornfeld, trinidad, supervisors, qajar, diplomas,
# Nearest to applications: weinstein, endogamous, arcueil, races, maia, nostratic, yong, patchwork,
# Nearest to numerous: forgiveness, might, scrooge, socketed, murphy, jane, dks, placards,
# Nearest to hold: engrams, stripe, andree, antecedent, surveying, anatoly, jovis, communaute,
# Nearest to gold: talked, partition, falco, photographed, alleged, spins, bsp, mb,
# Nearest to rise: dark, explore, patzig, students, jarrow, szczecin, chessboard, calendarists,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4568 0.0434 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3414 0.0423 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3276 0.0429 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2480 0.0418 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1877 0.0426 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1659 0.0424 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1028 0.0421 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0449 0.0427 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0221 0.0430 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0126 0.0422 sec/batch
# Nearest to was: wheel, traditional, proleptic, containers, forbids, bible, slidell, electoral,
# Nearest to over: nt, acquiring, tungusic, early, deluxe, bugzilla, raping, isbns,
# Nearest to these: gas, covered, nw, beauty, endless, greig, tennant, knit,
# Nearest to also: revive, at, caledonian, academy, optimize, repaid, webster, so,
# Nearest to such: virgil, took, civilian, yet, rix, half, humanity, cheltenham,
# Nearest to been: flow, settings, professional, darkens, permit, variety, even, undo,
# Nearest to their: serbo, traversed, seven, taking, searching, growth, cb, computer,
# Nearest to years: uncodified, searching, wishing, disagreement, hodge, vyacheslav, bulgar, zero,
# Nearest to derived: riff, northern, communications, greeting, rene, penises, thunder, others,
# Nearest to hit: briefly, increased, originally, sales, province, fanshawe, monophosphate, creatures,
# Nearest to woman: networked, a, academy, kornfeld, diplomas, trinidad, harpist, christology,
# Nearest to applications: yong, races, endogamous, arcueil, containing, banach, sammet, hajj,
# Nearest to numerous: might, forgiveness, scrooge, jane, murphy, dks, socketed, corinthians,
# Nearest to hold: engrams, stripe, antecedent, slow, andree, batted, rhine, bates,
# Nearest to gold: talked, partition, alleged, tumor, existed, spins, falco, bsp,
# Nearest to rise: dark, explore, students, decades, shocking, outlined, factsheet, rigidity,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9450 0.0438 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8911 0.0422 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9052 0.0433 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.9025 0.0429 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7998 0.0430 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8473 0.0430 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8241 0.0443 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7742 0.0438 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7776 0.0423 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8131 0.0431 sec/batch
# Nearest to was: wheel, electoral, forbids, containers, traditional, bible, replenish, lockheed,
# Nearest to over: nt, raping, tungusic, hsv, isbns, bugzilla, acquiring, deluxe,
# Nearest to these: kant, gas, beauty, nw, greig, covered, endless, paekche,
# Nearest to also: revive, conscience, caledonian, webster, acquaintances, manifested, reflection, optimize,
# Nearest to such: humanity, rix, virgil, really, half, percent, trash, cheltenham,
# Nearest to been: flow, professional, settings, impassable, permit, relation, darkens, conceptual,
# Nearest to their: dare, serbo, taking, traversed, apartments, searching, complies, career,
# Nearest to years: disagreement, wishing, uncodified, hodge, zero, searching, commonwealth, televisions,
# Nearest to derived: greeting, riff, northern, rene, communications, penises, graphemes, battles,
# Nearest to hit: briefly, sales, originally, newton, fanshawe, creatures, province, homogeneity,
# Nearest to woman: networked, a, trinidad, diplomas, kornfeld, christology, harpist, academy,
# Nearest to applications: containing, races, hudson, yong, banach, clock, bitwise, efficiency,
# Nearest to numerous: might, forgiveness, scrooge, murphy, jane, corinthians, dks, gyro,
# Nearest to hold: stripe, antecedent, engrams, andree, surveying, batted, rebuilding, slow,
# Nearest to gold: talked, partition, existed, alleged, spins, tumor, parthians, bsp,
# Nearest to rise: dark, explore, students, decades, outlined, rigidity, shocking, tide,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7971 0.0431 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7310 0.0437 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7347 0.0418 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7038 0.0429 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7428 0.0422 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7085 0.0431 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6967 0.0422 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7405 0.0430 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7091 0.0434 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6579 0.0433 sec/batch
# Nearest to was: wheel, electoral, forbids, traditional, seventy, lockheed, negotiations, bible,
# Nearest to over: nt, isbns, raping, bugzilla, hsv, tungusic, amur, deluxe,
# Nearest to these: kant, nw, greig, gas, covered, beauty, paekche, busiest,
# Nearest to also: caledonian, conscience, revive, acquaintances, fondness, segregation, inaccessible, repaid,
# Nearest to such: humanity, rix, virgil, browsers, really, cheltenham, trash, counteracting,
# Nearest to been: impassable, professional, flow, settings, prohibitions, tear, brienne, doubts,
# Nearest to their: dare, complies, serbo, taking, apartments, searching, cb, career,
# Nearest to years: zero, uncodified, disagreement, hodge, wishing, commonwealth, seven, carr,
# Nearest to derived: greeting, riff, rene, penises, graphemes, cherie, northern, petitioned,
# Nearest to hit: briefly, sales, originally, homogeneity, creatures, newton, mla, blast,
# Nearest to woman: networked, a, harpist, diplomas, trinidad, lolita, kornfeld, armstrong,
# Nearest to applications: bitwise, hudson, containing, psychosis, banach, sammet, endogamous, clock,
# Nearest to numerous: forgiveness, scrooge, might, murphy, jane, dks, gyro, summa,
# Nearest to hold: stripe, antecedent, andree, engrams, surveying, batted, rebuilding, communaute,
# Nearest to gold: talked, partition, existed, spins, parthians, tumor, alleged, aba,
# Nearest to rise: dark, explore, students, factsheet, chessboard, decades, shocking, tide,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6855 0.0437 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6532 0.0423 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6091 0.0418 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6342 0.0422 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6207 0.0428 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6344 0.0429 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5844 0.0315 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5562 0.0417 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5206 0.0418 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5062 0.0422 sec/batch
# Nearest to was: wheel, electoral, negotiations, colonia, forbids, lockheed, seventy, replenish,
# Nearest to over: nt, isbns, raping, bugzilla, amur, reexports, hsv, tungusic,
# Nearest to these: kant, greig, gas, inputs, covered, paekche, nw, endless,
# Nearest to also: caledonian, acquaintances, fondness, conscience, revive, tunku, cholas, roswell,
# Nearest to such: rix, denizens, browsers, stalking, counteracting, humanity, slow, really,
# Nearest to been: impassable, flow, settings, professional, prohibitions, doubts, permit, tgs,
# Nearest to their: dare, complies, taking, serbo, absorbs, rush, searching, apartments,
# Nearest to years: hodge, zero, commonwealth, uncodified, disagreement, infant, carr, wishing,
# Nearest to derived: greeting, riff, graphemes, cherie, penises, rene, inference, sponge,
# Nearest to hit: briefly, sales, creatures, originally, mla, blast, wetter, fanshawe,
# Nearest to woman: networked, diplomas, lolita, harpist, armstrong, trinidad, kornfeld, supervisors,
# Nearest to applications: bitwise, bit, containing, clock, psychosis, banach, efficiency, sammet,
# Nearest to numerous: forgiveness, scrooge, jane, might, dks, murphy, summa, socketed,
# Nearest to hold: antecedent, stripe, andree, surveying, engrams, jovis, innovator, communaute,
# Nearest to gold: talked, partition, existed, parthians, tumor, condenser, falco, spins,
# Nearest to rise: dark, explore, chessboard, factsheet, students, decades, tide, szczecin,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5226 0.0439 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4665 0.0429 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4640 0.0420 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5346 0.0425 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4905 0.0418 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4736 0.0421 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4609 0.0422 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4193 0.0424 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4494 0.0421 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4053 0.0423 sec/batch
# Nearest to was: electoral, wheel, colonia, had, lockheed, forbids, negotiations, oresund,
# Nearest to over: nt, isbns, raping, amur, bugzilla, hsv, reexports, tungusic,
# Nearest to these: kant, inputs, greig, covered, gas, because, potassium, paekche,
# Nearest to also: caledonian, tunku, attentive, acquaintances, calcium, roswell, cholas, fondness,
# Nearest to such: browsers, rix, denizens, stalking, really, counteracting, humanity, yet,
# Nearest to been: impassable, settings, variety, prohibitions, professional, tear, tgs, cryptozoologists,
# Nearest to their: dare, complies, taking, apartments, bisexuality, serbo, entailed, ancients,
# Nearest to years: infant, hodge, migration, zero, commonwealth, disagreement, carr, uncodified,
# Nearest to derived: greeting, graphemes, riff, cherie, sponge, reddish, enciphered, centripetal,
# Nearest to hit: sales, briefly, mla, creatures, wetter, blast, originally, newton,
# Nearest to woman: networked, diplomas, lolita, harpist, armstrong, kornfeld, christology, jordi,
# Nearest to applications: bitwise, bit, clock, containing, efficiency, specification, banach, psychosis,
# Nearest to numerous: forgiveness, scrooge, dks, might, summa, placards, defector, quesada,
# Nearest to hold: antecedent, stripe, andree, engrams, batted, jovis, innovator, anatoly,
# Nearest to gold: talked, partition, parthians, bsp, tumor, and, existed, condenser,
# Nearest to rise: explore, dark, chessboard, factsheet, decades, forestry, herds, szczecin,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4361 0.0444 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4204 0.0423 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4300 0.0421 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3749 0.0429 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3967 0.0419 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4132 0.0425 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3727 0.0426 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3360 0.0431 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3803 0.0427 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3601 0.0423 sec/batch
# Nearest to was: electoral, hatti, forbids, wheel, had, negotiations, voracious, forwarded,
# Nearest to over: nt, isbns, bugzilla, amur, tungusic, raping, hsv, reexports,
# Nearest to these: kant, greig, paekche, inputs, covered, absorbs, gas, changing,
# Nearest to also: caledonian, tunku, fondness, chomsky, cholas, postpone, xenia, attentive,
# Nearest to such: rix, denizens, browsers, stalking, really, counteracting, yet, approximate,
# Nearest to been: impassable, cryptozoologists, tear, settings, doubts, prohibitions, variety, chromosomes,
# Nearest to their: complies, dare, taking, searching, bisexuality, reconnect, slurred, apartments,
# Nearest to years: migration, infant, hodge, chromium, uncodified, zero, samkhya, carr,
# Nearest to derived: greeting, graphemes, cherie, centripetal, sponge, riff, fasttrack, reddish,
# Nearest to hit: sales, briefly, mla, creatures, originally, blast, wetter, songs,
# Nearest to woman: networked, diplomas, harpist, lolita, armstrong, kornfeld, christology, musial,
# Nearest to applications: bitwise, bit, clock, efficiency, containing, specification, banach, sammet,
# Nearest to numerous: dks, forgiveness, scrooge, might, quesada, summa, placards, defector,
# Nearest to hold: antecedent, stripe, engrams, batted, andree, jovis, demand, impressively,
# Nearest to gold: partition, talked, parthians, aba, falco, bsp, condenser, spins,
# Nearest to rise: explore, chessboard, dark, patzig, factsheet, decades, forestry, szczecin,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3681 0.0430 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3881 0.0427 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3564 0.0431 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3455 0.0426 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3735 0.0420 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3877 0.0439 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4094 0.0425 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3585 0.0426 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3143 0.0426 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3019 0.0422 sec/batch
# Nearest to was: electoral, had, seventy, negotiations, oresund, forwarded, forbids, hatti,
# Nearest to over: nt, bugzilla, isbns, amur, reexports, tungusic, jebel, hsv,
# Nearest to these: greig, kant, paekche, covered, inputs, troodos, redshifted, potassium,
# Nearest to also: cholas, tunku, caledonian, postpone, chomsky, omnipresent, biblically, xenia,
# Nearest to such: denizens, browsers, rix, really, stalking, proportionately, yet, approximate,
# Nearest to been: impassable, prohibitions, doubts, cryptozoologists, variety, settings, tgs, bangladeshis,
# Nearest to their: complies, dare, taking, slurred, ended, career, crypts, reconnect,
# Nearest to years: infant, migration, zero, chromium, hodge, samkhya, uncodified, birthrate,
# Nearest to derived: graphemes, greeting, cherie, consonant, sponge, centripetal, fasttrack, reddish,
# Nearest to hit: sales, mla, briefly, creatures, songs, blast, originally, fgm,
# Nearest to woman: lolita, networked, harpist, diplomas, armstrong, christology, musial, jordi,
# Nearest to applications: bit, bitwise, specification, clock, efficiency, sammet, connecting, computers,
# Nearest to numerous: dks, scrooge, quesada, placards, forgiveness, might, summa, defector,
# Nearest to hold: antecedent, stripe, engrams, batted, jovis, cavan, impressively, telling,
# Nearest to gold: partition, talked, spins, parthians, aba, condenser, nasl, falco,
# Nearest to rise: explore, chessboard, decades, factsheet, calendarists, aqsa, forestry, dark,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3382 0.0432 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2933 0.0426 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3596 0.0435 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3852 0.0429 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3768 0.0419 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2811 0.0420 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2870 0.0429 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3124 0.0422 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2345 0.0420 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2744 0.0428 sec/batch
# Nearest to was: electoral, hatti, had, oresund, stood, negotiations, forwarded, lockheed,
# Nearest to over: nt, bugzilla, isbns, reexports, amur, years, infant, jebel,
# Nearest to these: greig, paekche, kant, covered, troodos, inputs, potassium, zarqawi,
# Nearest to also: cholas, tunku, xenia, chomsky, omnipresent, biblically, limousines, lothian,
# Nearest to such: denizens, rix, really, browsers, approximate, proportionately, stalking, kl,
# Nearest to been: impassable, cryptozoologists, settings, variety, doubts, prohibitions, ainu, chlorination,
# Nearest to their: complies, career, dare, slurred, ended, reconnect, bisexuality, crypts,
# Nearest to years: infant, migration, zero, fertility, live, population, migrant, male,
# Nearest to derived: graphemes, greeting, consonant, centripetal, phonology, cherie, typology, reddish,
# Nearest to hit: sales, mla, songs, briefly, creatures, appeared, blast, fgm,
# Nearest to woman: lolita, diplomas, networked, harpist, jordi, armstrong, christology, musial,
# Nearest to applications: bitwise, specification, bit, clock, efficiency, sammet, chip, omitted,
# Nearest to numerous: dks, scrooge, quesada, placards, jane, defector, gyro, forgiveness,
# Nearest to hold: antecedent, stripe, engrams, jovis, batted, impressively, cavan, surveying,
# Nearest to gold: partition, talked, nasl, parthians, condenser, spins, hh, ore,
# Nearest to rise: chessboard, decades, explore, factsheet, forestry, aqsa, dark, calendarists,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2866 0.0440 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2821 0.0427 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3250 0.0198 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2400 0.0427 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1932 0.0419 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2059 0.0438 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2015 0.0426 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1829 0.0426 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2161 0.0433 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1462 0.0426 sec/batch
# Nearest to was: electoral, stood, had, hatti, oresund, lockheed, negotiations, forwarded,
# Nearest to over: nt, isbns, bugzilla, reexports, years, amur, hepworth, raping,
# Nearest to these: paekche, greig, troodos, kant, redshifted, prospering, covered, inputs,
# Nearest to also: cholas, xenia, tunku, omnipresent, chomsky, biblically, postpone, limousines,
# Nearest to such: rix, denizens, browsers, approximate, discordant, really, proportionately, stalking,
# Nearest to been: impassable, cryptozoologists, settings, variety, tgs, prohibitions, doubts, ainu,
# Nearest to their: complies, slurred, career, dare, ended, crypts, apartments, bisexuality,
# Nearest to years: infant, migration, zero, fertility, live, population, male, migrant,
# Nearest to derived: graphemes, greeting, consonant, typology, centripetal, phonology, northern, cherie,
# Nearest to hit: sales, mla, songs, hitting, briefly, creatures, team, blast,
# Nearest to woman: lolita, jordi, diplomas, networked, christology, armstrong, husband, harpist,
# Nearest to applications: bitwise, specification, clock, bit, sammet, efficiency, chip, dynamically,
# Nearest to numerous: dks, placards, scrooge, quesada, gyro, hawat, jane, might,
# Nearest to hold: antecedent, stripe, engrams, cavan, jovis, batted, impressively, surveying,
# Nearest to gold: partition, talked, nasl, and, parthians, photographed, falco, anagrams,
# Nearest to rise: chessboard, decades, explore, factsheet, aqsa, forestry, patzig, calendarists,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2021 0.0453 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1901 0.0426 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2204 0.0431 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1275 0.0428 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1583 0.0428 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1298 0.0431 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1321 0.0422 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1660 0.0421 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1598 0.0427 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1468 0.0426 sec/batch
# Nearest to was: stood, hatti, electoral, jehoiachin, oresund, lockheed, negotiations, had,
# Nearest to over: nt, isbns, bugzilla, years, reexports, hepworth, raping, hsv,
# Nearest to these: kant, troodos, paekche, greig, prospering, redshifted, potassium, inputs,
# Nearest to also: cholas, omnipresent, tunku, chomsky, list, xenia, limousines, postpone,
# Nearest to such: denizens, rix, browsers, approximate, stalking, proportionately, discordant, counting,
# Nearest to been: cryptozoologists, impassable, variety, settings, tgs, prohibitions, chromosomes, burkina,
# Nearest to their: complies, career, slurred, bisexuality, dare, apartments, reconnect, batter,
# Nearest to years: infant, migration, zero, fertility, live, birthrate, over, population,
# Nearest to derived: graphemes, greeting, typology, consonant, centripetal, northern, phonology, names,
# Nearest to hit: sales, mla, songs, groove, appeared, briefly, stalwart, creatures,
# Nearest to woman: lolita, jordi, christology, armstrong, husband, harpist, networked, musial,
# Nearest to applications: bitwise, specification, clock, sammet, efficiency, bit, dynamically, computers,
# Nearest to numerous: dks, scrooge, placards, quesada, hawat, shortfall, gyro, summa,
# Nearest to hold: antecedent, stripe, engrams, batted, impressively, unnumbered, jovis, pataphysics,
# Nearest to gold: partition, nasl, ore, parthians, talked, smelting, anagrams, mined,
# Nearest to rise: chessboard, decades, explore, patzig, factsheet, forestry, aqsa, jarrow,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1405 0.0435 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2092 0.0426 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1517 0.0427 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1499 0.0424 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1714 0.0427 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1752 0.0436 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1834 0.0430 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1428 0.0429 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1193 0.0436 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1497 0.0419 sec/batch
# Nearest to was: stood, electoral, jehoiachin, hatti, oresund, rabin, lockheed, ludovico,
# Nearest to over: isbns, years, nt, bugzilla, reexports, hepworth, amur, raping,
# Nearest to these: kant, troodos, paekche, redshifted, zarqawi, greig, inputs, prospering,
# Nearest to also: cholas, list, enjoys, omnipresent, xenia, biblically, tunku, chomsky,
# Nearest to such: denizens, rix, stalking, approximate, proportionately, discordant, browsers, really,
# Nearest to been: cryptozoologists, impassable, settings, variety, chromosomes, tempelhof, tgs, lurid,
# Nearest to their: career, complies, slurred, dare, reconnect, bisexuality, byronic, entertained,
# Nearest to years: infant, zero, migration, live, over, fertility, birth, population,
# Nearest to derived: graphemes, greeting, typology, northern, centripetal, consonant, names, phonology,
# Nearest to hit: sales, mla, songs, creatures, groove, stalwart, hitting, briefly,
# Nearest to woman: lolita, jordi, husband, harpist, christology, musial, children, networked,
# Nearest to applications: bitwise, specification, clock, recalculated, efficiency, sammet, omitted, arsenide,
# Nearest to numerous: dks, placards, scrooge, hawat, quesada, gyro, jane, shortfall,
# Nearest to hold: antecedent, stripe, engrams, batted, cavan, unnumbered, impressively, surveying,
# Nearest to gold: ore, smelting, partition, nasl, mined, anagrams, falco, talked,
# Nearest to rise: decades, chessboard, explore, patzig, factsheet, aqsa, forestry, risen,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1682 0.0434 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1442 0.0423 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1551 0.0424 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1867 0.0422 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1325 0.0432 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.0777 0.0427 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1487 0.0426 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1126 0.0426 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1741 0.0430 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2003 0.0431 sec/batch
# Nearest to was: stood, hatti, electoral, negotiations, subsequently, lockheed, had, ludovico,
# Nearest to over: years, isbns, nt, bugzilla, infant, amur, hepworth, reexports,
# Nearest to these: paekche, troodos, greig, kant, zarqawi, redshifted, prospering, pasted,
# Nearest to also: list, cholas, enjoys, biblically, omnipresent, lothian, chomsky, auchinleck,
# Nearest to such: denizens, rix, approximate, discordant, proportionately, feu, scouring, representable,
# Nearest to been: cryptozoologists, impassable, lurid, followings, burkina, tenants, posthumously, doubts,
# Nearest to their: career, complies, crypts, slurred, entertained, conscription, dare, ended,
# Nearest to years: infant, zero, migration, live, over, fertility, birth, birthrate,
# Nearest to derived: graphemes, greeting, northern, typology, cherie, consonant, names, fiorentino,
# Nearest to hit: sales, mla, stalwart, hitting, songs, creatures, beatles, briefly,
# Nearest to woman: lolita, husband, children, jordi, harpist, christology, musial, diplomas,
# Nearest to applications: bitwise, specification, sammet, efficiency, clock, arsenide, recalculated, bofh,
# Nearest to numerous: dks, placards, jane, quesada, scrooge, hawat, defector, murphy,
# Nearest to hold: antecedent, stripe, engrams, unnumbered, cavan, batted, impressively, surveying,
# Nearest to gold: ore, smelting, nasl, partition, fusible, mined, anagrams, falco,
# Nearest to rise: decades, chessboard, aqsa, patzig, factsheet, jarrow, explore, forestry,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1899 0.0438 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1144 0.0424 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1154 0.0422 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.0957 0.0431 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0310 0.0427 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1237 0.0421 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1272 0.0428 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1017 0.0422 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1675 0.0085 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0926 0.0432 sec/batch
# Nearest to was: stood, electoral, hatti, negotiations, lockheed, subsequently, ludovico, had,
# Nearest to over: years, isbns, nt, reexports, bugzilla, infant, amur, hepworth,
# Nearest to these: troodos, redshifted, prospering, kant, paekche, greig, overlap, inputs,
# Nearest to also: list, cholas, omnipresent, enjoys, biblically, limousines, tunku, chomsky,
# Nearest to such: denizens, rix, approximate, proportionately, representable, discordant, kl, browsers,
# Nearest to been: cryptozoologists, lurid, burkina, tempelhof, settings, impassable, variety, chlorination,
# Nearest to their: career, complies, slurred, dare, crypts, conscription, competent, bisexuality,
# Nearest to years: zero, infant, live, fertility, migration, over, birth, mortality,
# Nearest to derived: graphemes, greeting, typology, northern, phonology, centripetal, consonant, diphthong,
# Nearest to hit: sales, mla, hitting, stalwart, songs, beatles, blast, briefly,
# Nearest to woman: lolita, husband, jordi, harpist, christology, children, diplomas, musial,
# Nearest to applications: bitwise, specification, sammet, recalculated, clock, calculable, arsenide, efficiency,
# Nearest to numerous: dks, quesada, placards, jane, scrooge, favours, hawat, monkees,
# Nearest to hold: antecedent, stripe, engrams, unnumbered, impressively, surveying, batted, pataphysics,
# Nearest to gold: ore, mined, nasl, anagrams, fusible, smelting, partition, falco,
# Nearest to rise: decades, chessboard, patzig, explore, aqsa, factsheet, work, forestry,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0616 0.0439 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0553 0.0423 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0594 0.0417 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0198 0.0425 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0382 0.0434 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0166 0.0422 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0545 0.0420 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0570 0.0430 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0819 0.0424 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9928 0.0424 sec/batch
# Nearest to was: stood, hatti, negotiations, electoral, had, lockheed, jehoiachin, subsequently,
# Nearest to over: years, isbns, nt, bugzilla, reexports, aerated, amur, raping,
# Nearest to these: redshifted, paekche, troodos, greig, kant, prospering, pasted, zarqawi,
# Nearest to also: cholas, list, biblically, omnipresent, enjoys, tunku, xenia, in,
# Nearest to such: denizens, rix, approximate, representable, discordant, proportionately, protonated, kl,
# Nearest to been: cryptozoologists, impassable, tempelhof, lurid, burkina, variety, tenants, settings,
# Nearest to their: career, complies, crypts, slurred, ended, entertained, batter, dare,
# Nearest to years: zero, live, infant, over, birth, migration, fertility, birthrate,
# Nearest to derived: graphemes, greeting, typology, northern, transgenic, centripetal, fiorentino, separate,
# Nearest to hit: sales, hitting, mla, stalwart, blast, songs, rtf, briefly,
# Nearest to woman: husband, lolita, jordi, harpist, children, christology, couples, musial,
# Nearest to applications: bitwise, specification, sammet, recalculated, arsenide, analyzer, mechanical, efficiency,
# Nearest to numerous: dks, quesada, placards, jane, hawat, scrooge, murphy, favours,
# Nearest to hold: antecedent, stripe, engrams, unnumbered, pataphysics, batted, impressively, inescapable,
# Nearest to gold: mined, nasl, ore, partition, anagrams, fusible, smelting, falco,
# Nearest to rise: decades, chessboard, aqsa, factsheet, patzig, risen, forestry, explore,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0033 0.0434 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.9972 0.0425 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9891 0.0434 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0091 0.0421 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0396 0.0427 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 3.9876 0.0441 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0155 0.0421 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0816 0.0419 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0581 0.0425 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0044 0.0428 sec/batch
# Nearest to was: hatti, stood, electoral, negotiations, subsequently, jehoiachin, lockheed, proleptic,
# Nearest to over: years, isbns, nt, bugzilla, reexports, aerated, hepworth, hsv,
# Nearest to these: kant, overlap, paekche, redshifted, prospering, troodos, pasted, zarqawi,
# Nearest to also: list, cholas, biblically, enjoys, in, xenia, chomsky, omnipresent,
# Nearest to such: denizens, rix, approximate, representable, proportionately, discordant, kl, wallets,
# Nearest to been: cryptozoologists, tempelhof, burkina, variety, chlorination, lurid, introduction, sentinel,
# Nearest to their: career, complies, slurred, segmented, bisexuality, conscription, small, batter,
# Nearest to years: zero, live, infant, over, birth, migration, fertility, cabbie,
# Nearest to derived: graphemes, greeting, typology, names, transgenic, northern, centripetal, variables,
# Nearest to hit: sales, mla, hitting, stalwart, blast, songs, groove, rtf,
# Nearest to woman: husband, jordi, harpist, lolita, children, christology, couples, musial,
# Nearest to applications: bitwise, arsenide, specification, mechanical, recalculated, analyzer, sammet, hudson,
# Nearest to numerous: dks, hawat, quesada, scrooge, placards, jane, murphy, purporting,
# Nearest to hold: antecedent, stripe, engrams, unnumbered, pataphysics, inescapable, impressively, batted,
# Nearest to gold: mined, ore, nasl, anagrams, partition, fusible, smelting, falco,
# Nearest to rise: decades, chessboard, patzig, risen, explore, aqsa, work, quantify,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0383 0.0434 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0664 0.0421 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0388 0.0417 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0031 0.0428 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0549 0.0425 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0427 0.0434 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0193 0.0427 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0420 0.0430 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0604 0.0426 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0667 0.0421 sec/batch
# Nearest to was: stood, electoral, hatti, negotiations, subsequently, ludovico, proleptic, jehoiachin,
# Nearest to over: years, isbns, nt, bugzilla, amur, aerated, reexports, jebel,
# Nearest to these: overlap, kant, redshifted, troodos, paekche, prospering, zarqawi, morse,
# Nearest to also: list, cholas, enjoys, biblically, in, omnipresent, associated, lothian,
# Nearest to such: denizens, rix, approximate, discordant, proportionately, wallets, spice, representable,
# Nearest to been: cryptozoologists, lurid, introduction, followings, tempelhof, settings, sentinel, impassable,
# Nearest to their: career, complies, crypts, conscription, entertained, slurred, druids, bisexuality,
# Nearest to years: zero, live, infant, over, birth, migration, fertility, population,
# Nearest to derived: graphemes, greeting, typology, northern, transgenic, penises, names, norwegian,
# Nearest to hit: sales, mla, stalwart, rtf, songs, groove, hitting, beatles,
# Nearest to woman: husband, jordi, harpist, children, lolita, christology, couples, musial,
# Nearest to applications: specification, bitwise, mechanical, arsenide, recalculated, hudson, analyzer, bruxelles,
# Nearest to numerous: dks, placards, quesada, jane, hawat, scrooge, murphy, purporting,
# Nearest to hold: antecedent, stripe, engrams, inescapable, pataphysics, unnumbered, batted, cavan,
# Nearest to gold: ore, nasl, mined, partition, fusible, anagrams, smelting, repatriated,
# Nearest to rise: decades, chessboard, risen, patzig, aqsa, work, forestry, explore,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0368 0.0427 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9795 0.0423 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.9835 0.0428 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0227 0.0431 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0347 0.0427 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0883 0.0420 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1199 0.0429 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 3.9911 0.0428 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9853 0.0429 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0212 0.0426 sec/batch
# Nearest to was: hatti, electoral, stood, negotiations, lockheed, lamenting, jauron, unfortunately,
# Nearest to over: years, isbns, bugzilla, nt, amur, jebel, reexports, aerated,
# Nearest to these: troodos, overlap, redshifted, prospering, pasted, paekche, zarqawi, greig,
# Nearest to also: list, enjoys, in, cholas, biblically, lothian, resurgence, beginner,
# Nearest to such: denizens, rix, approximate, proportionately, discordant, kl, minerals, representable,
# Nearest to been: cryptozoologists, tenants, variety, burkina, commented, followings, unlikely, toby,
# Nearest to their: career, complies, slurred, bisexuality, conscription, segmented, crypts, entertained,
# Nearest to years: zero, live, infant, birth, over, migration, fertility, seven,
# Nearest to derived: graphemes, greeting, typology, northern, transgenic, names, lore, norwegian,
# Nearest to hit: sales, mla, stalwart, rtf, songs, pinocchio, hitting, groove,
# Nearest to woman: husband, couples, children, jordi, harpist, lolita, christology, infant,
# Nearest to applications: bitwise, arsenide, specification, sammet, mechanical, recalculated, analyzer, bruxelles,
# Nearest to numerous: dks, placards, quesada, murphy, scrooge, hawat, purporting, jane,
# Nearest to hold: antecedent, stripe, engrams, pataphysics, unnumbered, inescapable, batted, impressively,
# Nearest to gold: nasl, mined, fusible, ore, partition, smelting, anagrams, repatriated,
# Nearest to rise: decades, chessboard, work, patzig, aqsa, explore, risen, constricted,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9274 0.0443 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9989 0.0430 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.9926 0.0424 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9762 0.0431 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0379 0.0421 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.9975 0.0399 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9948 0.0423 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9516 0.0424 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9903 0.0430 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9307 0.0425 sec/batch
# Nearest to was: stood, hatti, unfortunately, electoral, had, negotiations, subsequently, succeeding,
# Nearest to over: years, isbns, nt, bugzilla, aerated, reexports, amur, vorkosigan,
# Nearest to these: troodos, overlap, redshifted, prospering, morse, kant, paekche, koresh,
# Nearest to also: list, cholas, enjoys, biblically, in, all, beginner, see,
# Nearest to such: denizens, rix, discordant, minerals, approximate, proportionately, protonated, representable,
# Nearest to been: cryptozoologists, burkina, followings, lurid, commented, seminomadic, tenants, settings,
# Nearest to their: career, complies, slurred, conscription, segmented, technik, entertained, bisexuality,
# Nearest to years: zero, live, over, infant, birth, fertility, migration, days,
# Nearest to derived: graphemes, greeting, typology, penises, northern, lore, trickster, interfering,
# Nearest to hit: sales, mla, stalwart, hitting, rtf, pinocchio, groove, fanshawe,
# Nearest to woman: husband, children, jordi, couples, christology, lolita, harpist, householder,
# Nearest to applications: bitwise, specification, arsenide, sammet, framework, recalculated, fedora, calculable,
# Nearest to numerous: dks, quesada, placards, hawat, purporting, jane, murphy, scrooge,
# Nearest to hold: antecedent, stripe, engrams, pataphysics, batted, inescapable, unnumbered, monotheism,
# Nearest to gold: nasl, mined, anagrams, fusible, ore, partition, smelting, repatriated,
# Nearest to rise: decades, chessboard, aqsa, work, explore, patzig, constricted, risen,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9261 0.0438 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.8869 0.0419 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9882 0.0419 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9607 0.0421 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9810 0.0429 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9654 0.0435 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8704 0.0430 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9025 0.0426 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8800 0.0426 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9328 0.0424 sec/batch
# Nearest to was: stood, hatti, unfortunately, jauron, electoral, his, lockheed, had,
# Nearest to over: years, isbns, aerated, nt, bugzilla, reexports, off, amur,
# Nearest to these: overlap, troodos, prospering, redshifted, kant, underlining, polyatomic, wort,
# Nearest to also: list, in, cholas, enjoys, all, beginner, and, see,
# Nearest to such: denizens, rix, protonated, wallets, approximate, proportionately, minerals, discordant,
# Nearest to been: burkina, cryptozoologists, tenants, variety, reflux, unlikely, seminomadic, ecologically,
# Nearest to their: career, complies, segmented, conscription, slurred, entertained, small, communities,
# Nearest to years: zero, live, over, infant, birth, migration, fertility, five,
# Nearest to derived: graphemes, greeting, typology, northern, lore, penises, transgenic, trickster,
# Nearest to hit: sales, mla, stalwart, hitting, groove, rtf, mays, suction,
# Nearest to woman: husband, children, couples, jordi, harpist, lolita, christology, infant,
# Nearest to applications: arsenide, bitwise, specification, irix, fedora, fluency, remain, recalculated,
# Nearest to numerous: dks, quesada, hawat, vermiculite, jane, placards, murphy, lakeside,
# Nearest to hold: antecedent, stripe, engrams, batted, pataphysics, unnumbered, inescapable, impressively,
# Nearest to gold: mined, nasl, anagrams, fusible, ore, smelting, repatriated, partition,
# Nearest to rise: decades, chessboard, aqsa, risen, work, explore, constricted, patzig,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9447 0.0440 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9564 0.0431 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9207 0.0426 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9695 0.0421 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0273 0.0426 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9074 0.0422 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9823 0.0425 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9776 0.0428 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9488 0.0422 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9278 0.0427 sec/batch
# Nearest to was: stood, hatti, unfortunately, electoral, succeeding, lamenting, his, jehoiachin,
# Nearest to over: years, isbns, bugzilla, nt, aerated, vorkosigan, reexports, raping,
# Nearest to these: overlap, kant, troodos, morse, prospering, redshifted, polyatomic, pasted,
# Nearest to also: list, in, see, cholas, enjoys, all, beginner, and,
# Nearest to such: denizens, rix, approximate, postalveolar, discordant, protonated, minerals, grasse,
# Nearest to been: cryptozoologists, burkina, commented, reflux, variety, lurid, evolution, unlikely,
# Nearest to their: career, complies, segmented, reconnect, disputing, bisexuality, conscription, slurred,
# Nearest to years: zero, live, over, infant, birth, migration, five, seven,
# Nearest to derived: graphemes, greeting, typology, lore, northern, transgenic, names, penises,
# Nearest to hit: sales, mla, stalwart, hitting, groove, rtf, fanshawe, afraid,
# Nearest to woman: couples, husband, children, jordi, harpist, christology, lolita, married,
# Nearest to applications: arsenide, bitwise, specification, mechanical, engineers, fedora, framework, sammet,
# Nearest to numerous: dks, quesada, vermiculite, hawat, series, murphy, legends, jane,
# Nearest to hold: antecedent, stripe, batted, pataphysics, engrams, inescapable, unnumbered, impressively,
# Nearest to gold: mined, nasl, anagrams, fusible, ore, smelting, repatriated, falco,
# Nearest to rise: decades, chessboard, work, quantify, aqsa, risen, explore, patzig,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9727 0.0434 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9594 0.0429 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9131 0.0426 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9625 0.0419 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9875 0.0430 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9699 0.0424 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9546 0.0429 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.8956 0.0428 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9345 0.0431 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0070 0.0422 sec/batch
# Nearest to was: stood, hatti, unfortunately, succeeding, negotiations, his, electoral, proleptic,
# Nearest to over: years, isbns, amur, bugzilla, aerated, in, s, nt,
# Nearest to these: overlap, troodos, zarqawi, kant, prospering, covered, changing, pasted,
# Nearest to also: list, in, cholas, see, enjoys, as, polynesia, all,
# Nearest to such: denizens, minerals, rix, discordant, postalveolar, postmillennial, proportionately, protonated,
# Nearest to been: burkina, tenants, lurid, adjudicate, commented, cryptozoologists, suspects, tempelhof,
# Nearest to their: career, complies, disputing, conscription, segmented, slurred, bisexuality, communities,
# Nearest to years: zero, over, live, infant, birth, migration, ago, fertility,
# Nearest to derived: graphemes, greeting, northern, typology, lore, names, transgenic, trickster,
# Nearest to hit: sales, hitting, mla, stalwart, mays, groove, afraid, fanshawe,
# Nearest to woman: couples, children, jordi, husband, christology, harpist, infant, tadeusz,
# Nearest to applications: arsenide, bitwise, irix, framework, fedora, engineers, specification, sammet,
# Nearest to numerous: dks, quesada, hawat, vermiculite, purporting, jane, namely, widely,
# Nearest to hold: antecedent, stripe, pataphysics, batted, inescapable, engrams, monotheism, impressively,
# Nearest to gold: mined, fusible, nasl, smelting, ore, silver, anagrams, repatriated,
# ...
# Nearest to numerous: including, widely, as, quesada, origins, evangelica, lakeside, vermiculite,
# Nearest to hold: batted, unchanged, sit, antecedent, nontechnical, monotheism, stripe, trafford,
# Nearest to gold: silver, fusible, mined, anagrams, outro, nasl, parthians, medal,
# Nearest to rise: chessboard, led, aqsa, constricted, decades, upwelling, abductions, rapidly,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8205 0.0442 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7073 0.0421 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.7530 0.0431 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7298 0.0429 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7473 0.0423 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.7958 0.0430 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8168 0.0429 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.7623 0.0419 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8258 0.0423 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8388 0.0428 sec/batch
# Nearest to was: early, stood, had, in, s, did, later, were,
# Nearest to over: and, s, under, of, isbns, years, in, not,
# Nearest to these: are, of, by, a, all, overlap, for, most,
# Nearest to also: in, and, of, a, the, as, on, see,
# Nearest to such: of, for, the, most, is, a, also, known,
# Nearest to been: commented, found, were, was, years, discovered, reported, several,
# Nearest to their: they, to, and, them, for, both, with, of,
# Nearest to years: live, year, zero, ago, five, over, days, birth,
# Nearest to derived: graphemes, lore, word, typology, trickster, origins, names, varangians,
# Nearest to hit: sales, hitting, hits, afraid, stalwart, rtf, appeared, runs,
# Nearest to woman: spacey, couples, married, womanhood, labia, servants, adjective, postpositions,
# Nearest to applications: remain, arsenide, deafness, bruxelles, fedora, infrequent, advances, zinc,
# Nearest to numerous: including, as, widely, quesada, origins, namely, vermiculite, lakeside,
# Nearest to hold: unchanged, antecedent, batted, monotheism, sit, bolt, engrams, inescapable,
# Nearest to gold: silver, fusible, mined, anagrams, medal, outro, discoverer, nasl,
# Nearest to rise: chessboard, led, aqsa, constricted, risen, upwelling, work, decades,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7754 0.0435 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8000 0.0424 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8070 0.0429 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8170 0.0421 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8083 0.0435 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8264 0.0438 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.7989 0.0434 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.7860 0.0420 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8008 0.0420 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8269 0.0421 sec/batch
# Nearest to was: early, in, later, were, had, he, did, the,
# Nearest to over: and, years, under, of, s, in, the, isbns,
# Nearest to these: are, a, by, of, for, most, all, some,
# Nearest to also: in, and, of, the, a, see, on, all,
# Nearest to such: of, for, the, most, is, unchained, postmillennial, while,
# Nearest to been: commented, found, were, years, discovered, was, have, earlier,
# Nearest to their: they, to, and, with, both, around, them, able,
# Nearest to years: live, zero, over, ago, year, five, days, two,
# Nearest to derived: graphemes, lore, word, typology, trickster, varangians, names, origins,
# Nearest to hit: sales, hitting, hits, rtf, stalwart, afraid, habitation, rectum,
# Nearest to woman: adjective, spacey, postpositions, couples, womanhood, labia, jordi, married,
# Nearest to applications: remain, bruxelles, fedora, deafness, arsenide, weinstein, infrequent, antiaircraft,
# Nearest to numerous: including, as, widely, quesada, origins, many, namely, were,
# Nearest to hold: sit, batted, unchanged, antecedent, monotheism, bolt, furor, stripe,
# Nearest to gold: silver, fusible, mined, anagrams, outro, nasl, medal, discoverer,
# Nearest to rise: led, chessboard, aqsa, upwelling, constricted, downfall, rapidly, decades,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8000 0.0431 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.7862 0.0429 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.7805 0.0428 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.7606 0.0427 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8700 0.0432 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8217 0.0427 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9247 0.0417 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8318 0.0426 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8448 0.0429 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7703 0.0439 sec/batch
# Nearest to was: early, in, were, did, had, he, stood, s,
# Nearest to over: and, under, years, s, of, in, the, a,
# Nearest to these: are, by, a, for, some, of, and, bau,
# Nearest to also: in, of, and, the, a, see, an, on,
# Nearest to such: of, for, is, the, also, with, and, most,
# Nearest to been: commented, found, were, several, years, have, in, was,
# Nearest to their: they, to, and, around, both, them, able, jeopardized,
# Nearest to years: zero, live, year, over, five, two, ago, birth,
# Nearest to derived: graphemes, word, lore, trickster, typology, varangians, names, market,
# Nearest to hit: sales, hitting, rtf, stalwart, hits, runs, afraid, habitation,
# Nearest to woman: adjective, spacey, postpositions, couples, male, female, jordi, labia,
# Nearest to applications: remain, fedora, bruxelles, deafness, irix, infrequent, weinstein, sammet,
# Nearest to numerous: including, widely, quesada, as, origins, many, lakeside, carried,
# Nearest to hold: batted, unchanged, bolt, monotheism, stripe, antecedent, sit, trafford,
# Nearest to gold: silver, fusible, mined, nasl, anagrams, medal, discoverer, outro,
# Nearest to rise: chessboard, led, aqsa, upwelling, constricted, rapidly, work, downfall,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7093 0.0430 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8255 0.0428 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7291 0.0422 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8376 0.0427 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.7514 0.0433 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8289 0.0421 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8303 0.0253 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.7637 0.0426 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7923 0.0426 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8022 0.0424 sec/batch
# Nearest to was: in, had, s, early, stood, the, he, were,
# Nearest to over: and, under, s, years, in, a, of, the,
# Nearest to these: are, by, all, for, a, most, of, and,
# Nearest to also: in, of, and, the, a, see, as, an,
# Nearest to such: of, the, for, is, most, often, with, also,
# Nearest to been: commented, found, were, in, several, have, was, years,
# Nearest to their: they, to, and, around, able, both, elephants, some,
# Nearest to years: live, year, zero, days, over, ago, birth, two,
# Nearest to derived: graphemes, word, typology, trickster, lore, varangians, geryon, origins,
# Nearest to hit: sales, hitting, rtf, stalwart, afraid, hits, runs, habitation,
# Nearest to woman: spacey, adjective, postpositions, womanhood, couples, servants, male, female,
# Nearest to applications: remain, bruxelles, deafness, sammet, fedora, irix, weinstein, presently,
# Nearest to numerous: including, widely, quesada, vermiculite, lakeside, as, origins, evangelica,
# Nearest to hold: batted, monotheism, unchanged, bolt, furor, antecedent, rc, engrams,
# Nearest to gold: silver, fusible, mined, anagrams, medal, outro, nasl, discoverer,
# Nearest to rise: chessboard, led, aqsa, constricted, upwelling, rapidly, work, droughts,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7737 0.0437 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7383 0.0426 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7527 0.0424 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7342 0.0435 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8026 0.0430 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.7702 0.0427 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8264 0.0430 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7002 0.0418 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7720 0.0423 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7335 0.0423 sec/batch
# Nearest to was: early, had, stood, did, were, s, he, later,
# Nearest to over: and, under, years, of, s, the, a, in,
# Nearest to these: are, by, of, and, for, a, in, the,
# Nearest to also: in, and, of, the, a, as, see, an,
# Nearest to such: of, for, the, is, also, with, most, and,
# Nearest to been: found, commented, were, in, have, several, discovered, years,
# Nearest to their: they, to, around, both, many, some, with, them,
# Nearest to years: live, zero, year, ago, over, birth, two, five,
# Nearest to derived: graphemes, word, typology, lore, trickster, market, varangians, geryon,
# Nearest to hit: sales, hitting, hits, runs, afraid, rtf, rectum, stalwart,
# Nearest to woman: spacey, womanhood, adjective, couples, female, married, male, labia,
# Nearest to applications: remain, irix, deafness, bruxelles, arsenide, fedora, weinstein, redoutable,
# Nearest to numerous: including, widely, vermiculite, as, by, quesada, lakeside, carried,
# Nearest to hold: batted, unchanged, sit, bolt, monotheism, rc, trafford, antecedent,
# Nearest to gold: silver, fusible, mined, medal, discoverer, anagrams, nasl, outro,
# Nearest to rise: led, chessboard, aqsa, constricted, upwelling, rapidly, risen, condensation,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.6915 0.0436 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7703 0.0421 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8036 0.0433 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7591 0.0425 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7599 0.0417 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8355 0.0424 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7825 0.0430 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7574 0.0455 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7623 0.0435 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.7892 0.0424 sec/batch
# Nearest to was: early, had, were, s, in, later, stood, did,
# Nearest to over: and, under, of, s, the, in, years, a,
# Nearest to these: are, by, of, for, tend, all, a, especially,
# Nearest to also: in, and, of, the, on, a, as, see,
# Nearest to such: of, the, for, is, also, most, by, a,
# Nearest to been: commented, found, were, have, several, discovered, years, has,
# Nearest to their: they, to, around, and, with, both, some, them,
# Nearest to years: live, zero, ago, year, birth, five, over, age,
# Nearest to derived: graphemes, word, typology, lore, trickster, names, market, varangians,
# Nearest to hit: sales, hitting, hits, afraid, rtf, stalwart, rectum, groove,
# Nearest to woman: spacey, womanhood, couples, adjective, married, postpositions, jordi, christology,
# Nearest to applications: remain, deafness, arsenide, weinstein, irix, sammet, bruxelles, hsk,
# Nearest to numerous: including, widely, as, quesada, saf, well, vermiculite, by,
# Nearest to hold: bolt, batted, unchanged, sit, monotheism, trafford, rc, numbered,
# Nearest to gold: silver, fusible, medal, mined, anagrams, nasl, discoverer, outro,
# Nearest to rise: led, chessboard, aqsa, work, constricted, upwelling, waned, rapidly,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8049 0.0440 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.7679 0.0428 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7566 0.0424 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.7828 0.0436 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8168 0.0439 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8073 0.0436 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.7567 0.0429 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.7658 0.0431 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7545 0.0420 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7434 0.0435 sec/batch
# Nearest to was: early, had, in, were, s, the, later, at,
# Nearest to over: and, of, under, s, the, years, in, a,
# Nearest to these: are, by, of, for, from, in, and, a,
# Nearest to also: in, of, the, and, a, see, an, as,
# Nearest to such: of, for, is, the, also, often, and, with,
# Nearest to been: found, commented, were, have, years, was, several, has,
# Nearest to their: they, to, and, with, around, them, some, allow,
# Nearest to years: zero, live, five, over, year, ago, two, age,
# Nearest to derived: graphemes, word, typology, trickster, lore, names, greek, varangians,
# Nearest to hit: sales, hitting, runs, stalwart, mays, batting, hits, afraid,
# Nearest to woman: womanhood, spacey, postpositions, adjective, female, labia, plural, couples,
# Nearest to applications: remain, arsenide, irix, deafness, bruxelles, weinstein, presently, oversee,
# Nearest to numerous: including, widely, by, as, many, well, were, these,
# Nearest to hold: bolt, sit, unchanged, rc, furor, monotheism, numbered, batted,
# Nearest to gold: silver, fusible, medal, mined, anagrams, discoverer, nasl, outro,
# Nearest to rise: led, aqsa, chessboard, constricted, upwelling, work, rapidly, negara,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8163 0.0426 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7814 0.0422 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8714 0.0421 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8686 0.0421 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8388 0.0426 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8052 0.0425 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.6643 0.0428 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8106 0.0423 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7125 0.0426 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8116 0.0427 sec/batch
# Nearest to was: early, in, had, s, were, stood, became, did,
# Nearest to over: and, under, of, s, the, years, a, in,
# Nearest to these: are, by, tend, for, all, a, some, have,
# Nearest to also: in, of, the, and, see, as, a, an,
# Nearest to such: of, for, often, is, the, with, as, like,
# Nearest to been: commented, has, found, have, years, were, reported, incorrect,
# Nearest to their: they, to, with, around, and, allow, both, them,
# Nearest to years: zero, live, year, birth, over, two, age, ago,
# Nearest to derived: graphemes, word, typology, lore, trickster, greek, varangians, gesenius,
# Nearest to hit: sales, hitting, stalwart, rtf, afraid, habitation, hits, runs,
# Nearest to woman: female, spacey, womanhood, male, adjective, postpositions, labia, couples,
# Nearest to applications: remain, discovered, deafness, bruxelles, arsenide, sammet, presently, irix,
# Nearest to numerous: including, widely, as, many, by, these, well, quesada,
# Nearest to hold: bolt, unchanged, nontechnical, monotheism, rc, furor, batted, trafford,
# Nearest to gold: silver, fusible, mined, medal, anagrams, discoverer, nasl, xau,
# Nearest to rise: led, chessboard, aqsa, constricted, rapidly, negara, upwelling, cooling,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.7689 0.0434 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7614 0.0428 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
