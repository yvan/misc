# %% [markdown]
# For testing a second gpu along with the primary gpu.

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.autograd import Variable
from torch.utils.data import DataLoader

# %%
torch.__version__, torch.cuda.is_available(), torch.cuda.device_count(), torch.cuda.current_device()
# Out:
# ('0.3.0.post4', True, 2, 0)

# %%
torch.cuda.set_device(1)

# %%
torch.cuda.current_device()
# Out:
# 1

# %%
import os
data_loc = os.path.join('/media', 'hdd1', 'data', 'mnist')
dataset = datasets.MNIST(data_loc, download=True, transform=transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))]))
loader = DataLoader(dataset=dataset,
                   batch_size=64,
                   shuffle=True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x)

model = Net()
if torch.cuda.is_available():
    model.cuda()

optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.5)

# %%
n_epochs = 100
model.train()
for epoch in range(n_epochs):
    for i, (data, targets) in enumerate(loader):
        if torch.cuda.is_available():
            data, targets = Variable(data).cuda(), Variable(targets).cuda()
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, targets)
        loss.backward()
        optimizer.step()
        if not i % 250:
            print('epoch {} batch {} loss {}'.format(epoch, i, loss))
# Out:
# /home/yvan/anaconda3/envs/pytorch/lib/python3.6/site-packages/ipykernel_launcher.py:17: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# epoch 0 batch 0 loss Variable containing:
#  2.3346
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 0 batch 250 loss Variable containing:
#  0.7444
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 0 batch 500 loss Variable containing:
#  0.4568
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 0 batch 750 loss Variable containing:
#  0.3555
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 1 batch 0 loss Variable containing:
#  0.4552
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 1 batch 250 loss Variable containing:
#  0.2911
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 1 batch 500 loss Variable containing:
#  0.3613
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 1 batch 750 loss Variable containing:
#  0.1802
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 2 batch 0 loss Variable containing:
#  0.3913
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 2 batch 250 loss Variable containing:
#  0.1883
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 2 batch 500 loss Variable containing:
#  0.2801
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 2 batch 750 loss Variable containing:
#  0.2852
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 3 batch 0 loss Variable containing:
#  0.1397
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 3 batch 250 loss Variable containing:
# 1.00000e-02 *
#   5.8587
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 3 batch 500 loss Variable containing:
#  0.1852
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 3 batch 750 loss Variable containing:
#  0.3641
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 4 batch 0 loss Variable containing:
#  0.2018
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 4 batch 250 loss Variable containing:
#  0.3068
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 4 batch 500 loss Variable containing:
#  0.2170
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 4 batch 750 loss Variable containing:
#  0.2286
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 5 batch 0 loss Variable containing:
#  0.2220
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 5 batch 250 loss Variable containing:
# 1.00000e-02 *
#   9.3592
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 5 batch 500 loss Variable containing:
# 1.00000e-02 *
#   8.6093
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 5 batch 750 loss Variable containing:
#  0.3156
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 6 batch 0 loss Variable containing:
#  0.2572
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 6 batch 250 loss Variable containing:
#  0.3646
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 6 batch 500 loss Variable containing:
#  0.2567
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 6 batch 750 loss Variable containing:
#  0.2398
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 7 batch 0 loss Variable containing:
#  0.1890
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 7 batch 250 loss Variable containing:
#  0.1881
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 7 batch 500 loss Variable containing:
#  0.1573
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 7 batch 750 loss Variable containing:
#  0.3456
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 8 batch 0 loss Variable containing:
#  0.2107
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 8 batch 250 loss Variable containing:
# 1.00000e-02 *
#   8.4190
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 8 batch 500 loss Variable containing:
#  0.1890
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 8 batch 750 loss Variable containing:
#  0.2495
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 9 batch 0 loss Variable containing:
#  0.1619
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 9 batch 250 loss Variable containing:
# 1.00000e-02 *
#   9.6668
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 9 batch 500 loss Variable containing:
#  0.3179
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 9 batch 750 loss Variable containing:
#  0.2394
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 10 batch 0 loss Variable containing:
# 1.00000e-02 *
#   5.6663
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 10 batch 250 loss Variable containing:
#  0.1190
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 10 batch 500 loss Variable containing:
# 1.00000e-02 *
#   7.6351
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 10 batch 750 loss Variable containing:
#  0.1340
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 11 batch 0 loss Variable containing:
#  0.1725
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 11 batch 250 loss Variable containing:
#  0.1166
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 11 batch 500 loss Variable containing:
#  0.1268
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 11 batch 750 loss Variable containing:
#  0.1600
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 12 batch 0 loss Variable containing:
#  0.1532
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 12 batch 250 loss Variable containing:
#  0.1852
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 12 batch 500 loss Variable containing:
#  0.1907
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 12 batch 750 loss Variable containing:
#  0.2389
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 13 batch 0 loss Variable containing:
# 1.00000e-02 *
#   6.3398
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 13 batch 250 loss Variable containing:
# 1.00000e-02 *
#   5.8148
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 13 batch 500 loss Variable containing:
#  0.2965
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 13 batch 750 loss Variable containing:
# 1.00000e-02 *
#   5.2321
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 14 batch 0 loss Variable containing:
#  0.1348
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 14 batch 250 loss Variable containing:
#  0.1953
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 14 batch 500 loss Variable containing:
#  0.1625
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 14 batch 750 loss Variable containing:
#  0.2165
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 15 batch 0 loss Variable containing:
#  0.2192
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 15 batch 250 loss Variable containing:
# 1.00000e-02 *
#   6.1743
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 15 batch 500 loss Variable containing:
#  0.1176
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 15 batch 750 loss Variable containing:
# 1.00000e-02 *
#   2.2083
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 16 batch 0 loss Variable containing:
#  0.1726
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 16 batch 250 loss Variable containing:
# 1.00000e-02 *
#   8.0132
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 16 batch 500 loss Variable containing:
#  0.1423
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 16 batch 750 loss Variable containing:
#  0.1459
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 17 batch 0 loss Variable containing:
# 1.00000e-02 *
#   5.0582
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 17 batch 250 loss Variable containing:
#  0.1915
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 17 batch 500 loss Variable containing:
#  0.1761
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 17 batch 750 loss Variable containing:
#  0.2036
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 18 batch 0 loss Variable containing:
#  0.2079
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 18 batch 250 loss Variable containing:
# 1.00000e-02 *
#   8.6136
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 18 batch 500 loss Variable containing:
# 1.00000e-02 *
#   9.1203
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 18 batch 750 loss Variable containing:
#  0.1829
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 19 batch 0 loss Variable containing:
# 1.00000e-02 *
#   9.4253
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 19 batch 250 loss Variable containing:
# 1.00000e-02 *
#   9.7112
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 19 batch 500 loss Variable containing:
#  0.2213
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 19 batch 750 loss Variable containing:
#  0.2101
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 20 batch 0 loss Variable containing:
# 1.00000e-02 *
#   6.3841
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 20 batch 250 loss Variable containing:
#  0.2362
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 20 batch 500 loss Variable containing:
# 1.00000e-02 *
#   9.3540
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
# epoch 20 batch 750 loss Variable containing:
#  0.1757
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 21 batch 0 loss Variable containing:
# 1.00000e-02 *
#   8.4118
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 21 batch 250 loss Variable containing:
# 1.00000e-02 *
#   2.8376
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 21 batch 500 loss Variable containing:
# 1.00000e-02 *
#   8.5087
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 21 batch 750 loss Variable containing:
#  0.1131
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 22 batch 0 loss Variable containing:
# 1.00000e-02 *
#   2.5057
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 22 batch 250 loss Variable containing:
#  0.2931
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 22 batch 500 loss Variable containing:
# 1.00000e-02 *
#   2.5143
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 22 batch 750 loss Variable containing:
#  0.1411
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 23 batch 0 loss Variable containing:
# 1.00000e-02 *
#   6.1146
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 23 batch 250 loss Variable containing:
#  0.3263
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 23 batch 500 loss Variable containing:
# 1.00000e-02 *
#   4.8768
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 23 batch 750 loss Variable containing:
#  0.2647
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 24 batch 0 loss Variable containing:
#  0.2098
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 24 batch 250 loss Variable containing:
#  0.1121
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 24 batch 500 loss Variable containing:
# 1.00000e-02 *
#   5.4926
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 24 batch 750 loss Variable containing:
#  0.1320
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 25 batch 0 loss Variable containing:
#  0.1537
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 25 batch 250 loss Variable containing:
# 1.00000e-02 *
#   6.5163
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 25 batch 500 loss Variable containing:
#  0.1322
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 25 batch 750 loss Variable containing:
# 1.00000e-02 *
#   2.3355
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 26 batch 0 loss Variable containing:
# 1.00000e-02 *
#   8.2666
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 26 batch 250 loss Variable containing:
#  0.1613
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 26 batch 500 loss Variable containing:
#  0.1989
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 26 batch 750 loss Variable containing:
# 1.00000e-02 *
#   8.8711
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 27 batch 0 loss Variable containing:
# 1.00000e-02 *
#   5.3285
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 27 batch 250 loss Variable containing:
#  0.1539
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 27 batch 500 loss Variable containing:
#  0.1517
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 27 batch 750 loss Variable containing:
# 1.00000e-02 *
#   9.8387
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 28 batch 0 loss Variable containing:
# 1.00000e-02 *
#   3.9425
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 28 batch 250 loss Variable containing:
#  0.1338
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 28 batch 500 loss Variable containing:
# 1.00000e-02 *
#   5.1928
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 28 batch 750 loss Variable containing:
# 1.00000e-02 *
#   8.2812
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 29 batch 0 loss Variable containing:
#  0.1034
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 29 batch 250 loss Variable containing:
#  0.1590
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 29 batch 500 loss Variable containing:
#  0.2481
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 29 batch 750 loss Variable containing:
#  0.1934
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 30 batch 0 loss Variable containing:
#  0.2187
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 30 batch 250 loss Variable containing:
# 1.00000e-02 *
#   8.6072
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 30 batch 500 loss Variable containing:
#  0.2019
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 30 batch 750 loss Variable containing:
#  0.1425
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 31 batch 0 loss Variable containing:
# 1.00000e-02 *
#   4.5563
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 31 batch 250 loss Variable containing:
#  0.2752
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 31 batch 500 loss Variable containing:
# 1.00000e-02 *
#   8.7640
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 31 batch 750 loss Variable containing:
#  0.1301
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 32 batch 0 loss Variable containing:
# 1.00000e-02 *
#   9.6582
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 32 batch 250 loss Variable containing:
#  0.1938
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 32 batch 500 loss Variable containing:
#  0.1505
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 32 batch 750 loss Variable containing:
# 1.00000e-02 *
#   2.6426
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 33 batch 0 loss Variable containing:
# 1.00000e-02 *
#   9.9756
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 33 batch 250 loss Variable containing:
#  0.1194
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 33 batch 500 loss Variable containing:
#  0.2272
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 33 batch 750 loss Variable containing:
# 1.00000e-02 *
#   3.9296
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 34 batch 0 loss Variable containing:
#  0.1824
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 34 batch 250 loss Variable containing:
# 1.00000e-02 *
#   9.1255
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 34 batch 500 loss Variable containing:
# 1.00000e-02 *
#   8.0111
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 34 batch 750 loss Variable containing:
#  0.1253
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 35 batch 0 loss Variable containing:
#  0.1174
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 35 batch 250 loss Variable containing:
#  0.1536
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 35 batch 500 loss Variable containing:
# 1.00000e-02 *
#   6.8243
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 35 batch 750 loss Variable containing:
#  0.1623
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 36 batch 0 loss Variable containing:
# 1.00000e-02 *
#   5.8158
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 36 batch 250 loss Variable containing:
#  0.1134
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 36 batch 500 loss Variable containing:
#  0.1924
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 36 batch 750 loss Variable containing:
# 1.00000e-02 *
#   6.3078
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 37 batch 0 loss Variable containing:
#  0.1091
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 37 batch 250 loss Variable containing:
# 1.00000e-02 *
#   4.2545
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 37 batch 500 loss Variable containing:
# 1.00000e-02 *
#   9.2949
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 37 batch 750 loss Variable containing:
#  0.1809
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 38 batch 0 loss Variable containing:
#  0.1799
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 38 batch 250 loss Variable containing:
#  0.1503
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 38 batch 500 loss Variable containing:
#  0.2293
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 38 batch 750 loss Variable containing:
# 1.00000e-02 *
#   2.2886
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 39 batch 0 loss Variable containing:
# 1.00000e-02 *
#   4.7072
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 39 batch 250 loss Variable containing:
#  0.1042
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 39 batch 500 loss Variable containing:
#  0.2550
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 39 batch 750 loss Variable containing:
# 1.00000e-02 *
#   2.1230
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 40 batch 0 loss Variable containing:
#  0.1660
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 40 batch 250 loss Variable containing:
# 1.00000e-02 *
#   6.2282
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 40 batch 500 loss Variable containing:
# 1.00000e-02 *
#   4.9199
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
# epoch 40 batch 750 loss Variable containing:
#  0.1374
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 41 batch 0 loss Variable containing:
# 1.00000e-02 *
#   7.1538
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 41 batch 250 loss Variable containing:
#  0.1471
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 41 batch 500 loss Variable containing:
# 1.00000e-02 *
#   5.8068
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 41 batch 750 loss Variable containing:
#  0.1404
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 42 batch 0 loss Variable containing:
# 1.00000e-02 *
#   2.3788
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 42 batch 250 loss Variable containing:
#  0.1260
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 42 batch 500 loss Variable containing:
# 1.00000e-02 *
#   9.2068
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 42 batch 750 loss Variable containing:
#  0.2150
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 43 batch 0 loss Variable containing:
#  0.1592
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 43 batch 250 loss Variable containing:
# 1.00000e-02 *
#   4.0629
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 43 batch 500 loss Variable containing:
# 1.00000e-02 *
#   1.4820
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 43 batch 750 loss Variable containing:
#  0.1630
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 44 batch 0 loss Variable containing:
#  0.1503
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 44 batch 250 loss Variable containing:
# 1.00000e-02 *
#   2.5027
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 44 batch 500 loss Variable containing:
#  0.1933
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 44 batch 750 loss Variable containing:
# 1.00000e-02 *
#   2.8721
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 45 batch 0 loss Variable containing:
#  0.1368
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 45 batch 250 loss Variable containing:
# 1.00000e-02 *
#   8.7232
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 45 batch 500 loss Variable containing:
# 1.00000e-02 *
#   9.7531
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 45 batch 750 loss Variable containing:
#  0.1490
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 46 batch 0 loss Variable containing:
# 1.00000e-02 *
#   1.1425
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 46 batch 250 loss Variable containing:
# 1.00000e-02 *
#   2.2604
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 46 batch 500 loss Variable containing:
# 1.00000e-02 *
#   7.4664
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 46 batch 750 loss Variable containing:
# 1.00000e-02 *
#   6.5198
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 47 batch 0 loss Variable containing:
#  0.1387
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 47 batch 250 loss Variable containing:
# 1.00000e-02 *
#   3.1936
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 47 batch 500 loss Variable containing:
#  0.3313
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 47 batch 750 loss Variable containing:
# 1.00000e-02 *
#   4.2963
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 48 batch 0 loss Variable containing:
# 1.00000e-02 *
#   8.7882
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 48 batch 250 loss Variable containing:
# 1.00000e-02 *
#   6.9968
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 48 batch 500 loss Variable containing:
# 1.00000e-02 *
#   3.0158
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 48 batch 750 loss Variable containing:
# 1.00000e-02 *
#   7.6252
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 49 batch 0 loss Variable containing:
# 1.00000e-02 *
#   7.1157
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 49 batch 250 loss Variable containing:
#  0.1661
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 49 batch 500 loss Variable containing:
# 1.00000e-02 *
#   5.6386
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 49 batch 750 loss Variable containing:
# 1.00000e-02 *
#   7.5449
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 50 batch 0 loss Variable containing:
# 1.00000e-02 *
#   4.8921
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 50 batch 250 loss Variable containing:
# 1.00000e-02 *
#   5.8655
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 50 batch 500 loss Variable containing:
# 1.00000e-02 *
#   7.2299
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 50 batch 750 loss Variable containing:
#  0.1640
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 51 batch 0 loss Variable containing:
# 1.00000e-02 *
#   2.4397
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 51 batch 250 loss Variable containing:
# 1.00000e-02 *
#   5.6882
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 51 batch 500 loss Variable containing:
#  0.3328
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 51 batch 750 loss Variable containing:
#  0.3665
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 52 batch 0 loss Variable containing:
# 1.00000e-02 *
#   3.6556
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 52 batch 250 loss Variable containing:
# 1.00000e-02 *
#   5.3032
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 52 batch 500 loss Variable containing:
# 1.00000e-02 *
#   5.1610
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 52 batch 750 loss Variable containing:
# 1.00000e-02 *
#   4.5266
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 53 batch 0 loss Variable containing:
# 1.00000e-02 *
#   7.3079
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 53 batch 250 loss Variable containing:
# 1.00000e-02 *
#   2.8282
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 53 batch 500 loss Variable containing:
# 1.00000e-02 *
#   3.6750
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 53 batch 750 loss Variable containing:
# 1.00000e-02 *
#   4.3059
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 54 batch 0 loss Variable containing:
# 1.00000e-02 *
#   5.4363
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 54 batch 250 loss Variable containing:
#  0.1371
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 54 batch 500 loss Variable containing:
#  0.1136
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 54 batch 750 loss Variable containing:
# 1.00000e-02 *
#   4.3492
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 55 batch 0 loss Variable containing:
#  0.2420
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 55 batch 250 loss Variable containing:
# 1.00000e-02 *
#   4.3782
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 55 batch 500 loss Variable containing:
#  0.1254
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 55 batch 750 loss Variable containing:
# 1.00000e-02 *
#   6.0080
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 56 batch 0 loss Variable containing:
# 1.00000e-02 *
#   6.1963
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 56 batch 250 loss Variable containing:
# 1.00000e-02 *
#   5.3259
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 56 batch 500 loss Variable containing:
#  0.1418
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 56 batch 750 loss Variable containing:
#  0.1863
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 57 batch 0 loss Variable containing:
# 1.00000e-02 *
#   9.6710
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 57 batch 250 loss Variable containing:
# 1.00000e-02 *
#   4.6606
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 57 batch 500 loss Variable containing:
# 1.00000e-02 *
#   7.1694
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 57 batch 750 loss Variable containing:
# 1.00000e-02 *
#   7.6074
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 58 batch 0 loss Variable containing:
#  0.1514
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 58 batch 250 loss Variable containing:
# 1.00000e-02 *
#   9.5533
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 58 batch 500 loss Variable containing:
# 1.00000e-03 *
#   7.5325
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 58 batch 750 loss Variable containing:
# 1.00000e-02 *
#   6.0079
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 59 batch 0 loss Variable containing:
#  0.1423
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 59 batch 250 loss Variable containing:
# 1.00000e-02 *
#   7.5014
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 59 batch 500 loss Variable containing:
#  0.1700
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 59 batch 750 loss Variable containing:
#  0.2756
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 60 batch 0 loss Variable containing:
# 1.00000e-02 *
#   5.2241
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
# epoch 60 batch 250 loss Variable containing:
# 1.00000e-02 *
#   6.7714
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 60 batch 500 loss Variable containing:
#  0.1196
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 60 batch 750 loss Variable containing:
# 1.00000e-02 *
#   8.2584
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 61 batch 0 loss Variable containing:
# 1.00000e-02 *
#   8.9525
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 61 batch 250 loss Variable containing:
# 1.00000e-02 *
#   8.8336
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 61 batch 500 loss Variable containing:
# 1.00000e-02 *
#   6.7794
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 61 batch 750 loss Variable containing:
#  0.1016
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 62 batch 0 loss Variable containing:
# 1.00000e-02 *
#   3.0911
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 62 batch 250 loss Variable containing:
# 1.00000e-02 *
#   8.8776
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 62 batch 500 loss Variable containing:
# 1.00000e-02 *
#   3.2230
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 62 batch 750 loss Variable containing:
# 1.00000e-02 *
#   4.4536
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 63 batch 0 loss Variable containing:
#  0.1583
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 63 batch 250 loss Variable containing:
# 1.00000e-02 *
#   7.4283
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 63 batch 500 loss Variable containing:
#  0.1443
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 63 batch 750 loss Variable containing:
#  0.1902
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 64 batch 0 loss Variable containing:
# 1.00000e-02 *
#   4.9946
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 64 batch 250 loss Variable containing:
# 1.00000e-02 *
#   3.5290
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 64 batch 500 loss Variable containing:
# 1.00000e-02 *
#   3.2765
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 64 batch 750 loss Variable containing:
# 1.00000e-02 *
#   1.8323
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 65 batch 0 loss Variable containing:
#  0.1301
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 65 batch 250 loss Variable containing:
#  0.1634
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 65 batch 500 loss Variable containing:
# 1.00000e-02 *
#   9.7260
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 65 batch 750 loss Variable containing:
# 1.00000e-02 *
#   7.6307
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 66 batch 0 loss Variable containing:
# 1.00000e-02 *
#   9.9966
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 66 batch 250 loss Variable containing:
# 1.00000e-02 *
#   1.7470
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 66 batch 500 loss Variable containing:
# 1.00000e-02 *
#   1.6638
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 66 batch 750 loss Variable containing:
#  0.1131
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 67 batch 0 loss Variable containing:
# 1.00000e-02 *
#   4.1301
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 67 batch 250 loss Variable containing:
# 1.00000e-02 *
#   6.4366
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 67 batch 500 loss Variable containing:
# 1.00000e-02 *
#   3.7853
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 67 batch 750 loss Variable containing:
# 1.00000e-02 *
#   2.0375
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 68 batch 0 loss Variable containing:
# 1.00000e-02 *
#   7.6538
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 68 batch 250 loss Variable containing:
#  0.2692
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 68 batch 500 loss Variable containing:
# 1.00000e-02 *
#   4.1204
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 68 batch 750 loss Variable containing:
# 1.00000e-02 *
#   9.2727
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 69 batch 0 loss Variable containing:
# 1.00000e-02 *
#   4.5430
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 69 batch 250 loss Variable containing:
# 1.00000e-02 *
#   4.0587
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 69 batch 500 loss Variable containing:
#  0.2579
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 69 batch 750 loss Variable containing:
#  0.1524
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 70 batch 0 loss Variable containing:
# 1.00000e-02 *
#   3.1086
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 70 batch 250 loss Variable containing:
#  0.1343
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 70 batch 500 loss Variable containing:
# 1.00000e-02 *
#   3.0956
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 70 batch 750 loss Variable containing:
#  0.1202
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 71 batch 0 loss Variable containing:
#  0.1674
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 71 batch 250 loss Variable containing:
# 1.00000e-02 *
#   2.9704
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 71 batch 500 loss Variable containing:
# 1.00000e-02 *
#   4.2866
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 71 batch 750 loss Variable containing:
# 1.00000e-02 *
#   2.1263
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 72 batch 0 loss Variable containing:
#  0.1098
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 72 batch 250 loss Variable containing:
# 1.00000e-02 *
#   5.8511
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 72 batch 500 loss Variable containing:
# 1.00000e-02 *
#   7.3653
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 72 batch 750 loss Variable containing:
# 1.00000e-02 *
#   2.3641
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 73 batch 0 loss Variable containing:
# 1.00000e-02 *
#   5.6964
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 73 batch 250 loss Variable containing:
#  0.1128
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 73 batch 500 loss Variable containing:
#  0.1270
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 73 batch 750 loss Variable containing:
# 1.00000e-02 *
#   6.2181
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 74 batch 0 loss Variable containing:
# 1.00000e-02 *
#   6.2598
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 74 batch 250 loss Variable containing:
#  0.1216
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 74 batch 500 loss Variable containing:
#  0.2268
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 74 batch 750 loss Variable containing:
# 1.00000e-03 *
#   9.0840
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 75 batch 0 loss Variable containing:
# 1.00000e-02 *
#   2.0562
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 75 batch 250 loss Variable containing:
# 1.00000e-02 *
#   2.4331
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 75 batch 500 loss Variable containing:
# 1.00000e-02 *
#   3.9225
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 75 batch 750 loss Variable containing:
#  0.1637
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 76 batch 0 loss Variable containing:
#  0.1197
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 76 batch 250 loss Variable containing:
# 1.00000e-02 *
#   4.5209
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 76 batch 500 loss Variable containing:
# 1.00000e-02 *
#   3.9576
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 76 batch 750 loss Variable containing:
# 1.00000e-02 *
#   3.9912
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 77 batch 0 loss Variable containing:
#  0.1210
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 77 batch 250 loss Variable containing:
# 1.00000e-02 *
#   3.6595
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 77 batch 500 loss Variable containing:
# 1.00000e-02 *
#   2.9507
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 77 batch 750 loss Variable containing:
# 1.00000e-02 *
#   4.0685
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 78 batch 0 loss Variable containing:
# 1.00000e-02 *
#   8.3612
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 78 batch 250 loss Variable containing:
# 1.00000e-02 *
#   3.6487
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 78 batch 500 loss Variable containing:
# 1.00000e-02 *
#   2.8959
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 78 batch 750 loss Variable containing:
# 1.00000e-02 *
#   6.6830
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 79 batch 0 loss Variable containing:
# 1.00000e-02 *
#   6.3447
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 79 batch 250 loss Variable containing:
#  0.1812
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
# epoch 79 batch 500 loss Variable containing:
#  0.1130
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 79 batch 750 loss Variable containing:
# 1.00000e-02 *
#   4.9325
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 80 batch 0 loss Variable containing:
# 1.00000e-02 *
#   9.1740
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 80 batch 250 loss Variable containing:
# 1.00000e-02 *
#   5.2508
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 80 batch 500 loss Variable containing:
# 1.00000e-02 *
#   5.7045
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 80 batch 750 loss Variable containing:
# 1.00000e-02 *
#   2.9051
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 81 batch 0 loss Variable containing:
# 1.00000e-02 *
#   4.1113
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 81 batch 250 loss Variable containing:
# 1.00000e-02 *
#   5.6073
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 81 batch 500 loss Variable containing:
# 1.00000e-02 *
#   8.8559
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 81 batch 750 loss Variable containing:
#  0.1419
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 82 batch 0 loss Variable containing:
# 1.00000e-02 *
#   4.8062
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 82 batch 250 loss Variable containing:
# 1.00000e-02 *
#   2.3840
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 82 batch 500 loss Variable containing:
# 1.00000e-02 *
#   5.6312
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 82 batch 750 loss Variable containing:
# 1.00000e-02 *
#   4.0736
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 83 batch 0 loss Variable containing:
# 1.00000e-02 *
#   1.4488
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 83 batch 250 loss Variable containing:
# 1.00000e-02 *
#   5.0920
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 83 batch 500 loss Variable containing:
#  0.1247
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 83 batch 750 loss Variable containing:
# 1.00000e-02 *
#   4.8278
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 84 batch 0 loss Variable containing:
#  0.1629
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 84 batch 250 loss Variable containing:
# 1.00000e-02 *
#   5.1474
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 84 batch 500 loss Variable containing:
# 1.00000e-02 *
#   1.7625
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 84 batch 750 loss Variable containing:
#  0.1224
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 85 batch 0 loss Variable containing:
# 1.00000e-02 *
#   1.2201
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 85 batch 250 loss Variable containing:
# 1.00000e-02 *
#   6.9801
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 85 batch 500 loss Variable containing:
# 1.00000e-02 *
#   9.1340
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 85 batch 750 loss Variable containing:
#  0.1852
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 86 batch 0 loss Variable containing:
#  0.1165
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 86 batch 250 loss Variable containing:
#  0.1646
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 86 batch 500 loss Variable containing:
#  0.1756
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 86 batch 750 loss Variable containing:
# 1.00000e-03 *
#   9.4912
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 87 batch 0 loss Variable containing:
# 1.00000e-02 *
#   7.8026
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 87 batch 250 loss Variable containing:
# 1.00000e-02 *
#   8.7060
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 87 batch 500 loss Variable containing:
#  0.1713
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 87 batch 750 loss Variable containing:
# 1.00000e-02 *
#   2.3456
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 88 batch 0 loss Variable containing:
#  0.1321
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 88 batch 250 loss Variable containing:
# 1.00000e-02 *
#   1.1876
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 88 batch 500 loss Variable containing:
# 1.00000e-02 *
#   9.0570
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 88 batch 750 loss Variable containing:
# 1.00000e-02 *
#   2.4264
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 89 batch 0 loss Variable containing:
#  0.1460
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 89 batch 250 loss Variable containing:
# 1.00000e-02 *
#   6.0634
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 89 batch 500 loss Variable containing:
#  0.1724
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 89 batch 750 loss Variable containing:
#  0.1054
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 90 batch 0 loss Variable containing:
#  0.1007
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 90 batch 250 loss Variable containing:
# 1.00000e-02 *
#   6.7438
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 90 batch 500 loss Variable containing:
# 1.00000e-02 *
#   2.3152
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 90 batch 750 loss Variable containing:
# 1.00000e-02 *
#   5.3142
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 91 batch 0 loss Variable containing:
# 1.00000e-02 *
#   3.8054
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 91 batch 250 loss Variable containing:
# 1.00000e-02 *
#   6.7614
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 91 batch 500 loss Variable containing:
# 1.00000e-02 *
#   3.6457
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 91 batch 750 loss Variable containing:
# 1.00000e-02 *
#   3.3414
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 92 batch 0 loss Variable containing:
#  0.1073
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 92 batch 250 loss Variable containing:
# 1.00000e-02 *
#   6.3604
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 92 batch 500 loss Variable containing:
# 1.00000e-02 *
#   3.4282
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 92 batch 750 loss Variable containing:
# 1.00000e-02 *
#   6.0769
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 93 batch 0 loss Variable containing:
# 1.00000e-02 *
#   5.0233
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 93 batch 250 loss Variable containing:
#  0.1266
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 93 batch 500 loss Variable containing:
# 1.00000e-02 *
#   7.4050
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 93 batch 750 loss Variable containing:
# 1.00000e-02 *
#   3.2241
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 94 batch 0 loss Variable containing:
# 1.00000e-02 *
#   3.8122
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 94 batch 250 loss Variable containing:
#  0.2663
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 94 batch 500 loss Variable containing:
# 1.00000e-02 *
#   1.6252
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 94 batch 750 loss Variable containing:
# 1.00000e-02 *
#   5.2451
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 95 batch 0 loss Variable containing:
# 1.00000e-02 *
#   5.3534
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 95 batch 250 loss Variable containing:
# 1.00000e-02 *
#   3.1242
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 95 batch 500 loss Variable containing:
# 1.00000e-02 *
#   3.8565
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 95 batch 750 loss Variable containing:
# 1.00000e-02 *
#   7.8702
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 96 batch 0 loss Variable containing:
# 1.00000e-02 *
#   4.6153
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 96 batch 250 loss Variable containing:
# 1.00000e-02 *
#   7.0995
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 96 batch 500 loss Variable containing:
# 1.00000e-02 *
#   5.9945
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 96 batch 750 loss Variable containing:
# 1.00000e-02 *
#   7.1723
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 97 batch 0 loss Variable containing:
# 1.00000e-02 *
#   5.0846
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 97 batch 250 loss Variable containing:
#  0.1755
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 97 batch 500 loss Variable containing:
# 1.00000e-02 *
#   8.2857
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 97 batch 750 loss Variable containing:
# 1.00000e-02 *
#   4.7986
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 98 batch 0 loss Variable containing:
# 1.00000e-02 *
#   5.5766
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 98 batch 250 loss Variable containing:
# 1.00000e-02 *
#   6.5879
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 98 batch 500 loss Variable containing:
# 1.00000e-02 *
#   4.0104
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
# epoch 98 batch 750 loss Variable containing:
# 1.00000e-02 *
#   8.2351
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 99 batch 0 loss Variable containing:
# 1.00000e-02 *
#   5.1495
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 99 batch 250 loss Variable containing:
# 1.00000e-02 *
#   7.5948
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 99 batch 500 loss Variable containing:
# 1.00000e-02 *
#   9.9957
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# epoch 99 batch 750 loss Variable containing:
#  0.2087
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
